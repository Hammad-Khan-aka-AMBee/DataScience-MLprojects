# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import sklearn.metrics as sm
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-72e68d26-402e-435d-8292-203cabb57fde" name="files[]" multiple disabled />
#      <output id="result-72e68d26-402e-435d-8292-203cabb57fde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hepatitis.data to hepatitis.data

# %%
import pandas as pd

# %%
data=pd.read_csv('hepatitis.data')

# %%
data.describe()
# Out:
#                 2          30         2.1         2.2         1.2
# count  154.000000  154.000000  154.000000  154.000000  154.000000
# mean     1.792208   41.272727    1.097403    1.844156    1.454545
# std      0.407051   12.574106    0.297473    0.363891    0.499554
# min      1.000000    7.000000    1.000000    1.000000    1.000000
# 25%      2.000000   32.000000    1.000000    2.000000    1.000000
# 50%      2.000000   39.000000    1.000000    2.000000    1.000000
# 75%      2.000000   50.000000    1.000000    2.000000    2.000000
# max      2.000000   78.000000    2.000000    2.000000    2.000000

# %%
X  =data[1:-54]
Y=data[1:-54]
Z= data[100:-1]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 20 columns):
# 2       154 non-null int64
# 30      154 non-null int64
# 2.1     154 non-null int64
# 1       154 non-null object
# 2.2     154 non-null int64
# 2.3     154 non-null object
# 2.4     154 non-null object
# 2.5     154 non-null object
# 1.1     154 non-null object
# 2.6     154 non-null object
# 2.7     154 non-null object
# 2.8     154 non-null object
# 2.9     154 non-null object
# 2.10    154 non-null object
# 1.00    154 non-null object
# 85      154 non-null object
# 18      154 non-null object
# 4.0     154 non-null object
# ?       154 non-null object
# 1.2     154 non-null int64
# dtypes: int64(5), object(15)
# memory usage: 24.1+ KB

# %%
X
# Out:
#     2  30  2.1  1  2.2 2.3 2.4 2.5  ... 2.9 2.10  1.00   85   18  4.0    ? 1.2
# 1   2  78    1  2    2   1   2   2  ...   2    2  0.70   96   32  4.0    ?   1
# 2   2  31    1  ?    1   2   2   2  ...   2    2  0.70   46   52  4.0   80   1
# 3   2  34    1  2    2   2   2   2  ...   2    2  1.00    ?  200  4.0    ?   1
# 4   2  34    1  2    2   2   2   2  ...   2    2  0.90   95   28  4.0   75   1
# 5   1  51    1  1    2   1   2   1  ...   2    2     ?    ?    ?    ?    ?   1
# 6   2  23    1  2    2   2   2   2  ...   2    2  1.00    ?    ?    ?    ?   1
# 7   2  39    1  2    2   1   2   2  ...   2    2  0.70    ?   48  4.4    ?   1
# 8   2  30    1  2    2   2   2   2  ...   2    2  1.00    ?  120  3.9    ?   1
# 9   2  39    1  1    1   2   2   2  ...   2    2  1.30   78   30  4.4   85   1
# 10  2  32    1  2    1   1   2   2  ...   2    2  1.00   59  249  3.7   54   1
# 11  2  41    1  2    1   1   2   2  ...   2    2  0.90   81   60  3.9   52   1
# ...

# %%
Z
# Out:
#      2  30  2.1  1  2.2 2.3 2.4 2.5  ... 2.9 2.10  1.00   85   18  4.0    ? 1.2
# 100  2  22    1  2    2   2   2   2  ...   2    2  0.70    ?   24    ?    ?   2
# 101  2  27    1  1    2   1   2   2  ...   2    2  2.40  168  227  3.0   66   2
# 102  2  51    1  1    2   1   1   1  ...   2    1  4.60  215  269  3.9   51   2
# 103  1  47    1  2    2   1   1   2  ...   1    1  1.70   86   20  2.1   46   2
# 104  2  25    1  2    2   2   2   2  ...   2    2  0.60    ?   34  6.4    ?   2
# 105  1  35    1  1    2   1   2   2  ...   1    2  1.50  138   58  2.6    ?   2
# 106  2  45    1  1    2   1   1   1  ...   2    2  2.30    ?  648    ?    ?   2
# 107  2  54    1  1    1   2   2   2  ...   2    2  1.00  155  225  3.6   67   2
# 108  1  33    1  1    2   1   1   2  ...   1    2  0.70   63   80  3.0   31   2
# 109  2   7    1  2    2   2   2   2  ...   2    2  0.70  256   25  4.2    ?   2
# 110  1  42    1  1    1   1   1   2  ...   2    2  0.50   62   68  3.8   29   2
# ...

# %%
data
# Out:
#      2  30  2.1  1  2.2 2.3 2.4 2.5  ... 2.9 2.10  1.00   85   18  4.0    ? 1.2
# 0    2  50    1  1    2   1   2   2  ...   2    2  0.90  135   42  3.5    ?   1
# 1    2  78    1  2    2   1   2   2  ...   2    2  0.70   96   32  4.0    ?   1
# 2    2  31    1  ?    1   2   2   2  ...   2    2  0.70   46   52  4.0   80   1
# 3    2  34    1  2    2   2   2   2  ...   2    2  1.00    ?  200  4.0    ?   1
# 4    2  34    1  2    2   2   2   2  ...   2    2  0.90   95   28  4.0   75   1
# 5    1  51    1  1    2   1   2   1  ...   2    2     ?    ?    ?    ?    ?   1
# 6    2  23    1  2    2   2   2   2  ...   2    2  1.00    ?    ?    ?    ?   1
# 7    2  39    1  2    2   1   2   2  ...   2    2  0.70    ?   48  4.4    ?   1
# 8    2  30    1  2    2   2   2   2  ...   2    2  1.00    ?  120  3.9    ?   1
# 9    2  39    1  1    1   2   2   2  ...   2    2  1.30   78   30  4.4   85   1
# 10   2  32    1  2    1   1   2   2  ...   2    2  1.00   59  249  3.7   54   1
# ...

# %%
num_train=int(0.8 * len(X))
num_test=len(X) - num_train

# %%
X_train, Y_train= X[:num_train],Y[:num_train]

# %%
X_val, Y_val=X[num_train:],Y[num_train:]

# %%
regressor=linear_model.LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-4d17c24ccad2> in <module>()
# ----> 1 regressor.fit(X_train,Y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
# ...

# %%
def vector(num_train,dim=10000):
  results=np.zeros((len(num_train), dim))
  for i, seq in enumerate(num_train):
    results[i,seq]=1.
  return results

# %%
X_train=vector(X)
X_val= vector(X)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-3ebc070ba849> in <module>()
# ----> 1 X_train=vector(X)
#       2 X_val= vector(X)
#
# <ipython-input-36-20353fb4b565> in vector(num_train, dim)
#       2   results=np.zeros((len(num_train), dim))
#       3   for i, seq in enumerate(num_train):
# ----> 4     results[i,seq]=1.
#       5   return results
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
len(X)
# Out:
# 99

# %%
len(Y)
# Out:
# 99

# %%
len(Z)
# Out:
# 53

# %%
Z
